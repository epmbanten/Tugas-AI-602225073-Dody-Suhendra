# %% [markdown]
# <a href="https://colab.research.google.com/github/epmbanten/Tugas-AI-602225073-Dody-Suhendra/blob/main/TugasKuliahDeepLearningObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from PIL import Image

# 1. Load a model (Menggunakan YOLOv11s sesuai contoh slide 26)
model = YOLO("yolo11s.pt")

# 2. Perform object detection on an image
# Pastikan nama file ini sama dengan gambar yang Anda upload di Langkah 3
results = model("Gambar_Demo.jpg")

# 3. Menampilkan hasil di Google Colab (Pengganti fungsi .show())
im_array = results[0].plot()
im = Image.fromarray(im_array[..., ::-1])
display(im)
# Out:
# image 1/1 /content/Gambar_Demo.jpg: 448x640 7 persons, 537.9ms
# Speed: 14.5ms preprocess, 537.9ms inference, 41.6ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=750x500>
